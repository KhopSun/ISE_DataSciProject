# %%
import os
import json
from pymongo import MongoClient
from pymongo.server_api import ServerApi
import certifi

# %% [markdown]
# ### Connect to MongoDB

# %%
uri = 'mongodb+srv://6638022021:ACacsp1384713847@dsdecluster.9dk4l.mongodb.net/?retryWrites=true&w=majority&appName=DsdeCluster'
# uri = "mongodb+srv://KTAP8:JhpxOn0CFlXE5mty@dsdedata.hv1co.mongodb.net/?retryWrites=true&w=majority&appName=DsdeData"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'), tlsCAFile=certifi.where())
# need certifi to fix the [SSL: CERTIFICATE_VERIFY_FAILED] 

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Initially cannot connect cuz wrong password for user in QuickStart
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %% [markdown]
# ### Drop Database function (Cannot create database via code)

# %%
# Drop the database
def drop_database():
    client.drop_database('DsdeDatabase')
    # client.drop_database('Data')
    print('Database has been dropped! (deleted)')
# drop_database()
# Out:
# Database has been dropped! (deleted)

# %%
# CANNOT create database using code, gotta create manually in MongoDB

# %% [markdown]
# ### From local files to MongoDB

# %%
# Define the base path of the folders
# Replace with the actual path to your folders (2018-2023)
def add_to_mongo(folder_name, collection_name, database_name):
    db = client[database_name]  # Replace with your database name
    collection = db[collection_name]
    for file in os.listdir(folder_name): # name of folder in the same directory
        with open(os.path.join(folder_name, file), 'r') as f:
            data = json.load(f)
        f.close()
        collection.insert_one(data)
        print(f'finish inserting {file}')
    print("Data insertion complete!")

# %%
add_to_mongo('SelectedData', 'data_given', 'DsdeDatabase')
# Out:
# finish inserting 3721.json
# finish inserting 2833.json
# finish inserting 13232.json
# finish inserting 729.json
# finish inserting 16030.json
# finish inserting 6523.json
# finish inserting 6489.json
# finish inserting 3371.json
# finish inserting 683.json
# finish inserting 13662.json
# finish inserting 12970.json
# finish inserting 379.json
# finish inserting 16460.json
# finish inserting 9286.json
# finish inserting 13398.json
# finish inserting 19795.json
# finish inserting 6173.json
# finish inserting 18887.json
# finish inserting 2999.json
# finish inserting 2130.json
# finish inserting 12423.json
# finish inserting 17621.json
# finish inserting 16933.json
# finish inserting 7332.json
# finish inserting 7298.json
# finish inserting 2560.json
# finish inserting 12073.json
# finish inserting 16899.json
# finish inserting 20102.json
# finish inserting 17271.json
# finish inserting 12589.json
# finish inserting 8497.json
# finish inserting 18184.json
# finish inserting 7762.json
# ...

# %%
add_to_mongo('ScrapedData', 'data_scraped', 'DsdeDatabase')
# Out:
# finish inserting 729.json
# finish inserting 683.json
# finish inserting 379.json
# finish inserting 396.json
# finish inserting 816.json
# finish inserting 115.json
# finish inserting 545.json
# finish inserting 400.json
# finish inserting 953.json
# finish inserting 284.json
# finish inserting 791.json
# finish inserting 512.json
# finish inserting 142.json
# finish inserting 841.json
# finish inserting 904.json
# finish inserting 457.json
# finish inserting 292.json
# finish inserting 768.json
# finish inserting 338.json
# finish inserting 787.json
# finish inserting 857.json
# finish inserting 154.json
# finish inserting 504.json
# finish inserting 441.json
# finish inserting 912.json
# finish inserting 695.json
# finish inserting 380.json
# finish inserting 553.json
# finish inserting 103.json
# finish inserting 800.json
# finish inserting 945.json
# finish inserting 416.json
# finish inserting 251.json
# finish inserting 601.json
# finish inserting 314.json
# ...
