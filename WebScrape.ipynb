# %%
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# ### From Website into File

# %%
url = 'https://www.elsevier.com/products/journals?query=&page=1&sortBy=relevance'

# %%
page = requests.get(url)

# %%
soup = BeautifulSoup(page.text, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="en-us">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width" name="viewport"/>
#   <link href="https://analytics.notify.elsevier.com" rel="preconnect"/>
#   <link href="https://sp.notify.elsevier.com" rel="preconnect"/>
#   <link href="https://cdn.cookielaw.org" rel="preconnect"/>
#   <link href="https://js-agent.newrelic.com" rel="preconnect"/>
#   <link href="https://images.ctfassets.net" rel="preconnect"/>
#   <link href="/images/elsevier-favicon.png" rel="icon" type="image/png"/>
#   <link href="/images/elsevier-favicon.svg" rel="icon" type="image/svg+xml"/>
#   <link href="/images/elsevier-apple-touch-icon.png" rel="apple-touch-icon"/>
#   <link href="/manifest.json" rel="manifest"/>
#   <meta content="0-8Ig3YtfzbeUxQdZ-TM_y8P_se41D4JrW3e0o8xgdk" name="google-site-verification"/>
#   <script>
# ...

# %%
html = soup.prettify()
with open('output.html', 'w') as f:
    f.write(html)

# %% [markdown]
# ### Analysing file

# %%
with open('output.html', 'r') as f:
    html = f.read()
f.close()
soup = BeautifulSoup(html, 'html.parser')

# %%
paragraphs = soup.find_all('p')
for paragraph in paragraphs:
    text = paragraph.get_text()
    print(text)
# Out:
#         Unfortunately we don't fully support your browser. If you have the option to, please upgrade to a newer version or use
#
#
#           Mozilla Firefox
#
#
#         ,
#
#
#           Microsoft Edge
#
#
#         ,
#
#
#           Google Chrome
#
#
#         , or Safari 14 or newer. If you are unable to, and need support, please
#
#
#           send us your feedback
#
#
#         .
#
#
#
#          We'd appreciate your feedback.
#
#
#
#           Tell us what you think!
#
#
#            opens in new tab/window
#
#
#
#
#
#                 Choose the journal that’s right for you. Browse through over 2,900 Elsevier titles across all areas of science, so you’ll always find the best match for your research. Search by keyword, filter by subject area or access type and sort by relevance.
#
#
#                Elsevier's Journal Finder matches your abstract to journals where your manuscript is most likely to be sent to peer review.
#
#
# ...

# %%
titles = soup.find_all('h1', class_='title')
for title in titles:
    text = title.get_text()
    print(text)

# %%
withclass = soup.find_all(class_=True)
# print(withclass)
# print(withclass[0])
names = [element['class'] for element in withclass]
print(names)
# Out:
# [['no-js'], ['_99wljg2e', '_99wljg4b'], ['_1gzv7750', '_16jmeqb8w', '_16jmeqb54', '_16jmeqb2w', '_16jmeqb6o', '_16jmeqb1s', '_16jmeqb182', '_16jmeqb1eq', '_16jmeqb1ev', '_16jmeqbxc', '_16jmeqb19y', '_16jmeqb15g'], ['gv4p8b0', '_16jmeqb166', '_16jmeqb167', '_16jmeqbs8', '_16jmeqb16m'], ['s2iygv0', '_16jmeqbx8', '_16jmeqb158'], ['_1i1ov3x0'], ['_1kbq9x82', '_1kbq9x84', '_1kbq9x85', '_1kbq9x88'], [], ['gv4p8b0', '_16jmeqb166', '_16jmeqb167'], ['_16jmeqb1k', '_16jmeqb18y', '_16jmeqb1eq', '_16jmeqb1ev'], ['gv4p8b0', '_16jmeqb166', '_16jmeqb167'], ['_16jmeqb1k', '_16jmeqb18y', '_16jmeqb1eq', '_16jmeqb1ev'], ['gv4p8b0', '_16jmeqb166', '_16jmeqb167'], ['_16jmeqb1k', '_16jmeqb18y', '_16jmeqb1eq', '_16jmeqb1ev'], ['gv4p8b0', '_16jmeqb166', '_16jmeqb167'], ['_16jmeqb1k', '_16jmeqb18y', '_16jmeqb1eq', '_16jmeqb1ev'], ['gv4p8b0', '_16jmeqb166', '_16jmeqb167'], ['s2iygv2', '_16jmeqbx8'], ['_99wljg4c', '_16jmeqb2w', '_16jmeqb6o', '_16jmeqb19i'], ['_1kbq9x82', '_1kbq9x84', '_1kbq9x85', '_1kbq9x88'],
# ...

# %% [markdown]
#  Does NOT work

# %% [markdown]
# ### Analysing with Selenium and BeautifulSoup (Elsevier)

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

# %%
chrome_options = webdriver.ChromeOptions()
browser = webdriver.Chrome(options=chrome_options)

# %%
url = 'https://www.elsevier.com/products/journals?query=&page=1&sortBy=relevance'
browser.get(url=url)

# %%
browser.find_element(By.CSS_SELECTOR, 'button[class^="_1d3he28a _16jmeqbts _16jmeqbuk _16jmeqbvc _16jmeqbw4 _16jmeqb1o _16jmeqbo _16jmeqb8 _16jmeqb1eq _16jmeqb1cm _16jmeqb1cr _16jmeqb1cw _16jmeqb1d1 _16jmeqb1f8 _1d3he285 _16jmeqb8k _16jmeqb8q _16jmeqb4s _16jmeqb4y _16jmeqb2w _16jmeqb6o _16jmeqb182 _16jmeqb18c _16jmeqb18h _16jmeqb19y _16jmeqb1ad _16jmeqb1d1 _16jmeqb1w _16jmeqb28"]').click()

# %% [markdown]
# ### Analysing with Selenium and BeautifulSoup (Science Direct)

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

# %%
chrome_options = webdriver.ChromeOptions()
browser = webdriver.Chrome(options=chrome_options)

# %%
# Open website
url = 'https://www.sciencedirect.com/' # Website main page
browser.get(url=url)

# %%
# Click sign-in
browser.find_element(By.CSS_SELECTOR, 'a[class^="anchor text-s u-clr-grey8 gh-move-to-spine u-hide-from-print u-margin-l-left anchor-secondary gh-icon-btn anchor-medium anchor-icon-left anchor-with-icon"]').click()

# %%
# Click Accept cookies
browser.find_element(By.CSS_SELECTOR, 'button[id^="onetrust-accept-btn-handler"]').click()

# %%
# Input email
email_input = browser.find_element(By.CSS_SELECTOR, 'input[id^="bdd-email"]')
email_input.click()
email = '6638022021@student.chula.ac.th'
email_input.send_keys(email)

# %%
# Click submit
browser.find_element(By.CSS_SELECTOR, 'button[id^="bdd-els-searchBtn"]').click()

# %%
# Click select Chulalongkorn University
browser.find_element(By.CSS_SELECTOR, 'button[value^="selectedShibInst"]').click()

# %% [markdown]
# Then we're stuck with the website sending the email to give us access link for 48 hours

# %% [markdown]
# ### Analysing with Selenium and BeautifulSoup, and Scholarly (Google Scholar)

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

# %%
chrome_options = webdriver.ChromeOptions()
browser = webdriver.Chrome(options=chrome_options)

# %%
# Open website
url = 'https://scholar.google.com'
browser.get(url=url)

# %%
# Input search topic
input_box = browser.find_element(By.CSS_SELECTOR, 'input[id^="gs_hdr_tsi"]')
input_box.click()
topic = 'academic'
input_box.send_keys(topic)

# %%
# Click search
browser.find_element(By.CSS_SELECTOR, 'button[id^="gs_hdr_tsb"]').click()

# %%
# Input email
email_input = browser.find_element(By.CSS_SELECTOR, 'input[id^="bdd-email"]')
email_input.click()
email = '6638022021@student.chula.ac.th'
email_input.send_keys(email)

# %%
# Click custom filter 
browser.find_element(By.CSS_SELECTOR, 'a[id^="gs_res_sb_yyc"]').click()

# %%
# Enter years
start_input = browser.find_element(By.CSS_SELECTOR, 'input[id^="gs_as_ylo"]')
start_input.click()
start_input.send_keys('2018')
# end_input = browser.find_element(By.CSS_SELECTOR, 'input[name^="as_yhi"]')
end_input = browser.find_element(by = By.NAME, value = "as_yhi")
# end_input.click()
# end_input.send_keys('2023')

# %% [markdown]
# Cannot click the input box for ending year, idk why, but whatever

# %%
# Click search
browser.find_element(By.CSS_SELECTOR, 'button[class^=" gs_btn_lsb"]').click()

# %% [markdown]
# Each paper in Google Scholar is too different in format, so will not use Selenium for this method

# %% [markdown]
# Try using Python Scholarly to scrape instead

# %% [markdown]
# Github for how to use Scholarly
# https://gist.github.com/hideojoho/e9dd5967c726cfae391bc382d5701ffb

# %%
from scholarly import scholarly

# %%
# Get an iterator for the author results
search_query = scholarly.search_author('Steven A Cholewiak')
# Retrieve the first result from the iterator
first_author_result = next(search_query)
scholarly.pprint(first_author_result)
# Out:
# b"{'affiliation': 'Applied Vision Scientist at Google LLC',\n 'citedby': 634,\n 'email_domain': '@google.com',\n 'filled': False,\n 'interests': ['Depth Cues',\n               '3D Shape',\n               'Shape from Texture & Shading',\n               'Naive Physics',\n               'Haptics'],\n 'name': 'Steven A. Cholewiak, PhD',\n 'scholar_id': '4bahYMkAAAAJ',\n 'source': 'SEARCH_AUTHOR_SNIPPETS',\n 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=4bahYMkAAAAJ'}"

# %% [markdown]
# Can either get from a specific author or an organization. However, neither has the information needed for the darhboard. So, this approach is now aborted.

# %% [markdown]
# ### After trying everything, turns out that nothing works cuz using Selenium gets blocked by Google, and Scholarly gives insufficient information.

# %% [markdown]
# ### Use data from arxiv instead

# %%
import requests
import random
import time
import xmltodict  # For converting XML to JSON
import json
# from pymongo import MongoClient
# from pymongo.server_api import ServerApi
import re
import os

# %%
# MongoDB URI and client setup
# uri = "mongodb+srv://KTAP8:JhpxOn0CFlXE5mty@dsdedata.hv1co.mongodb.net/?retryWrites=true&w=majority&appName=DsdeData"
# client = MongoClient(uri, server_api=ServerApi('1'))
# db = client['DsdeData']  # Database name
# collection = db['arxivScraped']  # New collection to store scraped data

# %%
def fetch_arxiv_data_as_json(query, max_results=10, max_retries=5):
    # base URL for the arXiv API endpoint used to search for data
    base_url = "https://export.arxiv.org/api/query"
    # dict containing search params to be sent to API
    params = { 
        "search_query": f"all:{query}",
        "max_results": max_results, # num of results to return
    }
    retry_count = 0
    delay = 1  # Initial delay in seconds

    while retry_count < max_retries:
        response = requests.get(base_url, params=params)
        if response.status_code == 200: # successful request
            # Convert XML to JSON
            data_dict = xmltodict.parse(response.content)
            # Convert dict to JSON-compatible format
            return json.loads(json.dumps(data_dict))
        elif response.status_code == 429: # rate limit exceeded
            print("Rate limit hit. Retrying...")
            time.sleep(delay)
            delay *= 2  # Exponential backoff
            retry_count += 1
        else:
            print(f"Failed to fetch data. HTTP Status code: {response.status_code}")
            return None
    print("Max retries exceeded.")
    return None

# %%
queries = [
    "Agricultural", "Bio", "Arts", "Human", "Business", "Management", "Account",
    "Chemical Engineering", "Computer", "Decision", "Dentist", "Earth", "Economic",
    "Finance", "Energy", "Engineering", "Environment", "Health", "Immun",
    "Material science", "Math", "Medicine", "Neuroscience", "Nursing", "Pharma",
    "Physic", "Psychology", "Social", "Veterinary", "Multidisciplinary"
]

subject_map = {
    "AGRI": ["Agricultural", "Bio"], 
    "ARTS": ["Arts"], 
    "BIOC": ["Human"],
    "BUSI": ["Business", "Management", "Account"], 
    "CENG": ["Chemical Engineering"],
    "CHEM": ["Chem"], "COMP": ["Computer"], 
    "DECI": ["Decision"], "DENT": ["Dentist"],
    "EART": ["Earth"], "ECON": ["Economic", "Finance"], 
    "ENER": ["Energy"],
    "ENGI": ["Engineering"], "ENVI": ["Environment"], 
    "HEAL": ["Health"],
    "IMMU": ["Immun"], 
    "MATE": ["Material science"], 
    "MATH": ["Math"],
    "MEDI": ["Medicine"], 
    "NEUR": ["Neuroscience"], 
    "NURS": ["Nursing"],
    "PHAR": ["Pharma"], 
    "PHYS": ["Physic"], 
    "PSYC": ["Psychology"],
    "SOCI": ["Social"], 
    "VETE": ["Veterinary"], 
    "MULT": ["Multidisciplinary"]
}

# %%
def map_subject(value):
    for key, values in subject_map.items():
        if value in values:
            return key
    return value

# %%
# in the journal ref --> pattern for the year of the ref is different, we gotta extract the year and the text this way
def extract_year_and_text(text):
    if (text == None):
        return [None, None]
    # Regular expression to find a year between 1800 and 2024
    year_pattern = r'\b(14[0-9]{2}|15[0-9]{2}|16[0-9]{2}|17[0-9]{2}|18[0-9]{2}|19[0-9]{2}|20[0-2][0-4])\b'

    # Search for the year in the text
    match = re.search(year_pattern, text)

    if match:
        year = match.group(0)  # Extract the matched year
        # Remove the year from the text
        remaining_text = text.replace(year, '').strip()
        return [year, remaining_text]
    else:
        return ["Unknown", text]  # No year found, return the original text

# %%
results = []
i = 1
while len(results) < 1000:
    query = random.choice(queries)
    arxiv_data = fetch_arxiv_data_as_json(query, max_results=25)
    if arxiv_data is not None:
        batch = []
        for entry in arxiv_data['feed']['entry']:
            if ('title' in entry) and ('author' in entry) and ('summary' in entry) and ('published' in entry) and ('arxiv:journal_ref' in entry):
                title = entry['title']
                authors = entry['author']
                if (type(authors) == list):
                    author_names = [author['name'] for author in authors]
                else:
                    author_names = [authors['name']]
                summary = entry['summary']
                publishing_date = (str(entry['published']).split('T'))[0]
                if '#text' in entry['arxiv:journal_ref']:
                    journal_ref = entry['arxiv:journal_ref']['#text']
                else:
                    journal_ref = None

                ref_year, ref_text = extract_year_and_text(journal_ref)
                if ((ref_year == None) and (ref_text == None)):
                    ref = None
                else:
                    ref = {ref_year: ref_text}

                coredata = {"title": title}

                document = {
                    "reference": ref,
                    "abstracts": summary,  # corrected typo
                    "correspondences": None,
                    "affiliation": None,
                    "publishedDate": publishing_date,
                    "coredata": coredata,
                    "language": "eng",
                    "authorKeywords": None,
                    "subjectArea": {map_subject(query): list()},
                    "authors": author_names
                }
                print(f'inserting: {title}')
                batch.append(document)
            else:
                pass
        # Insert batch into collection
        if batch:
            # collection.insert_many(batch)
            results.extend(batch)
            for j in batch:
                with open(os.path.join('ScrapedData', str(i)+'.json'), 'w') as ff:
                    json.dump(j, ff, indent=4)
                ff.close()
                i += 1
            print(f'Inserted batch of {len(batch)} documents.') 

    # Delay between requests to prevent rate limits
    time.sleep(2)  # Increase delay slightly if rate limit is still an issue
    print(len(results))
# Out:
# inserting: Value-Based Inventory Management
# inserting: Architecture of Network Management Tools for Heterogeneous System
# inserting: A conceptual framework of Intelligent Management Control System for
#   Higher Education
# inserting: Project Risk Management Model Based on PRINCE2 and Scrum Frameworks
# inserting: Performance of Network and Service Monitoring Frameworks
# inserting: Location Management in IP-based Future LEO Satellite Networks: A Review
# inserting: Conception of a management tool of Technology Enhanced Learning
#   Environments
# Inserted batch of 7 documents.
# 7
# inserting: The Link Between Standardization and Economic Growth: A Bibliometric
#   Analysis
# inserting: An Application of Hölder's Inequality to Economics
# inserting: Impact of digital economic activity on regional economic growth: A Case
#   study from northern Minas Gerais between 2009 To 2018
# inserting: A global economic policy uncertainty index from principal component
#   analysis
# ...
